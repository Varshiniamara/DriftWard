# %% [markdown]
# # DriftWarden — Initial Model Training
#
# Train the fault detector on the **AI4I 2020** reference split from UCI.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

import pandas as pd
from utils.model_utils import train_model, save_model, evaluate_model

ref = pd.read_csv(ROOT / 'data' / 'ai4i_reference.csv')
model = train_model(ref)
save_model(model)
print(evaluate_model(model, ref))
